# %%
import numpy as np

# %% [markdown]
# ## Resource:
# https://www.fueleconomy.gov/feg/ws/index.shtml#vehicle

# %%
data = np.genfromtxt("vehicles_sub.csv", delimiter=';')
print(data)
# Out:
# [[  1985.  -2750.]
#  [  1985. -12500.]
#  [  1985.   -250.]
#  ...
#  [  1993.  -2750.]
#  [  1993.  -2750.]
#  [  1993.  -8250.]]

# %%
data.shape
# Out:
# (47107, 2)

# %% [markdown]
# We split the initial database to only show year and youSaveSpend features from database
#
# youSaveSpend - you save/spend over 5 years compared to an average car ($). Savings are positive; a greater amount spent yields a negative number. For dual fuel vehicles, this is the cost savings for gasoline

# %%
data[0:12, :]
# Out:
# array([[  1985.,  -2750.],
#        [  1985., -12500.],
#        [  1985.,   -250.],
#        [  1985., -12500.],
#        [  1993.,  -7250.],
#        [  1993.,  -2250.],
#        [  1993.,  -1000.],
#        [  1993.,  -1250.],
#        [  1993.,   -500.],
#        [  1993.,  -1000.],
#        [  1993.,   -500.],
#        [  1993.,  -2750.]])

# %%
import matplotlib.pyplot as plt
# ensure that plots are displayed inside the notebook
# %matplotlib inline

# %%
x = data[:, 0]
y = data[:, 1]
plt.scatter(x, y);             # the semicolon stops jupyter from printing the result of the last function call

# %%
plt.scatter(x, y, s=3, alpha=0.2)
plt.xlabel('year of production')
plt.ylabel('youSpendRate');
